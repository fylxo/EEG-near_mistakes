# %% [markdown]
# # Interactive Theta Analysis Notebook
#
# This notebook provides an interactive environment for running theta oscillation analysis around Near Mistake (NM) events.
#
# **Key Benefits:**
# - Load `all_eeg_data.pkl` once and keep in memory
# - Run single session or multi-session analyses quickly
# - Easy parameter modification
# - Interactive results visualization
#
# **Workflow:**
# 1. Run the setup cell to load data and import functions
# 2. Use the analysis cells to run analyses with different parameters
# 3. Modify parameters as needed and re-run

# %% [markdown]
# ## 1. Setup and Data Loading
#
# **Run this cell once to load all data into memory.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import sys
import pandas as pd
from typing import Dict, List, Tuple, Optional, Union
from collections import defaultdict
import warnings

# Add src/core to path for imports
sys.path.append(os.path.join('src', 'core'))

# Import analysis functions
from nm_theta_analysis import analyze_session_nm_theta_roi, load_session_data
from nm_theta_multi_session import analyze_rat_multi_session, load_all_sessions_for_rat
from electrode_utils import get_channels, load_electrode_mappings, ROI_MAP

print("📦 Loading all EEG data into memory...")
print("This may take a moment but will speed up all subsequent analyses.")

# Load all data once
pkl_path = 'data/processed/all_eeg_data.pkl'
with open(pkl_path, 'rb') as f:
    all_eeg_data = pickle.load(f)

print(f"✅ Data loaded successfully!")
print(f"   Total sessions: {len(all_eeg_data)}")

# Load electrode mappings
electrode_mappings = load_electrode_mappings()
print(f"   Electrode mappings loaded for {len(electrode_mappings)} rats")

# Display available rats
rat_ids = set()
for session in all_eeg_data:
    rat_ids.add(session.get('rat_id', 'unknown'))

print(f"\n🐭 Available rats: {sorted(rat_ids)}")
print(f"🧠 Available ROIs: {list(ROI_MAP.keys())}")

# Display session summary
session_summary = {}
for i, session in enumerate(all_eeg_data):
    rat_id = session.get('rat_id', 'unknown')
    if rat_id not in session_summary:
        session_summary[rat_id] = []
    session_summary[rat_id].append({
        'index': i,
        'date': session.get('session_date', 'unknown'),
        'nm_events': len(session.get('nm_peak_times', [])),
        'eeg_shape': session['eeg'].shape if 'eeg' in session else 'N/A'
    })

print(f"\n📊 Session Summary:")
for rat_id, sessions in session_summary.items():
    print(f"   Rat {rat_id}: {len(sessions)} sessions, total NM events: {sum(s['nm_events'] for s in sessions)}")
# Out:
# 📦 Loading all EEG data into memory...
# This may take a moment but will speed up all subsequent analyses.
# ✅ Data loaded successfully!
#    Total sessions: 306
#    Electrode mappings loaded for 14 rats
#
# 🐭 Available rats: ['10501', '1055', '10592', '10593', '422', '441', '442', '531', '532', '9151', '9441', '9442', '9591', '9592']
# 🧠 Available ROIs: ['frontal', 'motor', 'ss', 'hippocampus', 'visual']
#
# 📊 Session Summary:
#    Rat 10501: 18 sessions, total NM events: 2538
#    Rat 1055: 23 sessions, total NM events: 3725
#    Rat 10592: 6 sessions, total NM events: 1087
#    Rat 10593: 12 sessions, total NM events: 2099
#    Rat 422: 35 sessions, total NM events: 6585
#    Rat 441: 30 sessions, total NM events: 5551
#    Rat 442: 37 sessions, total NM events: 7960
#    Rat 531: 36 sessions, total NM events: 5241
#    Rat 532: 28 sessions, total NM events: 5787
#    Rat 9151: 19 sessions, total NM events: 3200
#    Rat 9441: 8 sessions, total NM events: 1611
#    Rat 9442: 24 sessions, total NM events: 4618
#    Rat 9591: 7 sessions, total NM events: 1672
#    Rat 9592: 23 sessions, total NM events: 4192

# %% [markdown]
# ## 2. Quick Data Explorer
#
# Use this cell to quickly explore specific sessions.

# %%
# === PARAMETERS ===
session_index = 180  # Change this to explore different sessions

# === EXPLORATION ===
session = all_eeg_data[session_index]
print(f"📋 Session {session_index} Details:")
print(f"   Rat ID: {session.get('rat_id', 'unknown')}")
print(f"   Date: {session.get('session_date', 'unknown')}")
print(f"   EEG shape: {session['eeg'].shape}")
print(f"   Sampling rate: ~{1/np.median(np.diff(session['eeg_time'].flatten())):.0f} Hz")
print(f"   Duration: {session['eeg_time'].flatten()[-1]:.1f} seconds")
print(f"   NM events: {len(session['nm_peak_times'])}")
print(f"   NM sizes: {np.unique(session['nm_sizes'])}")

# Show available channels for this rat
rat_id = session.get('rat_id', 'unknown')
if rat_id in electrode_mappings.index:
    print(f"\n🧠 Available ROI channels for rat {rat_id}:")
    for roi_name, roi_channels in ROI_MAP.items():
        try:
            channels = get_channels(rat_id, roi_name, electrode_mappings)
            print(f"   {roi_name}: {channels}")
        except:
            print(f"   {roi_name}: Not available")
else:
    print(f"\n⚠️  No electrode mapping found for rat {rat_id}")
# Out:
# 📋 Session 180 Details:
#    Rat ID: 531
#    Date: 170820
#    EEG shape: (32, 476189)
#    Sampling rate: ~200 Hz
#    Duration: 2340.6 seconds
#    NM events: 31
#    NM sizes: [1. 2. 3.]
#
# ⚠️  No electrode mapping found for rat 531

# %% [markdown]
# ## 3. Single Session Analysis
#
# Analyze theta oscillations for a single session. Modify parameters as needed.

# %%
# %matplotlib qt

# %%
# === ANALYSIS PARAMETERS ===
session_index = 70                    # Which session to analyze
roi_specification = [2,29,31,32]      # ROI name or list of channels [1, 2, 3]
freq_range = (2, 10)                 # Frequency range in Hz
n_freqs = 25                         # Number of log-spaced frequencies
window_duration = 1.0                # Event window duration (±0.5s)
n_cycles_factor = 3.0                # Cycles per frequency factor
save_results = True                  # Whether to save results
show_plots = True                    # Whether to show plots

print(f"🔬 Running Single Session Analysis...")
print(f"   Session: {session_index}")
print(f"   ROI: {roi_specification}")
print(f"   Frequency range: {freq_range[0]}-{freq_range[1]} Hz ({n_freqs} frequencies)")
print(f"   Window: ±{window_duration/2:.1f}s around events")

# Get session data (no need to load from file!)
session_data = all_eeg_data[session_index]
rat_id = session_data.get('rat_id', 'unknown')
session_date = session_data.get('session_date', 'unknown')

print(f"   Rat ID: {rat_id}")
print(f"   Date: {session_date}")
print(f"   NM events: {len(session_data['nm_peak_times'])}")

# Run analysis
try:
    results = analyze_session_nm_theta_roi(
        session_data=session_data,
        roi_or_channels=roi_specification,
        freq_range=freq_range,
        n_freqs=n_freqs,
        window_duration=window_duration,
        n_cycles_factor=n_cycles_factor,
        save_path=f'results/single_session_{rat_id}_{session_date}' if save_results else None,
        mapping_df=electrode_mappings,
        show_plots=show_plots
    )
    
    print(f"\n✅ Analysis completed successfully!")
    print(f"   ROI channels used: {results['roi_channels']}")
    print(f"   Frequencies: {results['freqs'][0]:.2f} - {results['freqs'][-1]:.2f} Hz")
    print(f"   Event windows analyzed: {list(results['normalized_windows'].keys())}")
    
    # Store results for later use
    last_single_session_results = results
    
except Exception as e:
    print(f"❌ Analysis failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🔬 Running Single Session Analysis...
#    Session: 70
#    ROI: [2, 29, 31, 32]
#    Frequency range: 2-10 Hz (25 frequencies)
#    Window: ±0.5s around events
#    Rat ID: 422
#    Date: 100720
#    NM events: 163
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [2, 29, 31, 32]
# ✓ Resulting channel indices: [20, 21, 23, 24]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 1.57e-09 - 7.36e-01
#   Channel 20 z-score range: -1.06 - 11.96
# Processing channel 21 (2/4)
#   Channel 21 power range: 9.54e-10 - 2.08e+00
#   Channel 21 z-score range: -1.04 - 18.71
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.21e-09 - 5.60e-01
#   Channel 23 z-score range: -0.91 - 17.32
# Processing channel 24 (4/4)
#   Channel 24 power range: 5.83e-10 - 2.76e-01
#   Channel 24 z-score range: -1.03 - 13.38
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.00 - 8.51
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720
# Main results: results/single_session_422_100720\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
#
# ✅ Analysis completed successfully!
#    ROI channels used: [20, 21, 23, 24]
#    Frequencies: 2.00 - 10.00 Hz
#    Event windows analyzed: [1.0, 2.0, 3.0]

# %%
for channel_index in range(1, 33): 
    results = analyze_session_nm_theta_roi(
        session_data=session_data,
        roi_or_channels=[channel_index],
        freq_range=freq_range,
        n_freqs=n_freqs,
        window_duration=window_duration,
        n_cycles_factor=n_cycles_factor,
        save_path=f'results/single_session_{rat_id}_{session_date}_ch{channel_index}' if save_results else None,
        mapping_df=electrode_mappings,
        show_plots=show_plots
    )
# Out:
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [1]
# ✓ Resulting channel indices: [10]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [10]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [10]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 10 (1/1)
#   Channel 10 power range: 7.15e-10 - 3.79e-01
#   Channel 10 z-score range: -0.96 - 14.69
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.96 - 14.69
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch1
# Main results: results/single_session_422_100720_ch1\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch1\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch1\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [2]
# ✓ Resulting channel indices: [21]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [21]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [21]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 21 (1/1)
#   Channel 21 power range: 9.54e-10 - 2.08e+00
#   Channel 21 z-score range: -1.04 - 18.71
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.04 - 18.71
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch2
# Main results: results/single_session_422_100720_ch2\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch2\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch2\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [3]
# ✓ Resulting channel indices: [25]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [25]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [25]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 25 (1/1)
#   Channel 25 power range: 1.06e-08 - 8.89e-01
#   Channel 25 z-score range: -1.02 - 12.59
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.02 - 12.59
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch3
# Main results: results/single_session_422_100720_ch3\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch3\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch3\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [4]
# ✓ Resulting channel indices: [26]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [26]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [26]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 26 (1/1)
#   Channel 26 power range: 5.45e-10 - 6.98e-01
#   Channel 26 z-score range: -1.03 - 12.93
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 12.93
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch4
# Main results: results/single_session_422_100720_ch4\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch4\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch4\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [5]
# ✓ Resulting channel indices: [27]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [27]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [27]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 27 (1/1)
#   Channel 27 power range: 5.43e-10 - 7.55e-01
#   Channel 27 z-score range: -1.03 - 15.50
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 15.50
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch5
# Main results: results/single_session_422_100720_ch5\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch5\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch5\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [6]
# ✓ Resulting channel indices: [28]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [28]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [28]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 28 (1/1)
#   Channel 28 power range: 1.87e-08 - 8.03e-01
#   Channel 28 z-score range: -1.03 - 14.90
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 14.90
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch6
# Main results: results/single_session_422_100720_ch6\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch6\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch6\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [7]
# ✓ Resulting channel indices: [29]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [29]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [29]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 29 (1/1)
#   Channel 29 power range: 3.29e-10 - 6.87e-01
#   Channel 29 z-score range: -1.03 - 18.42
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 18.42
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch7
# Main results: results/single_session_422_100720_ch7\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch7\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch7\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [8]
# ✓ Resulting channel indices: [30]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [30]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [30]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 30 (1/1)
#   Channel 30 power range: 2.51e-09 - 6.50e-01
#   Channel 30 z-score range: -1.03 - 16.83
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 16.83
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch8
# Main results: results/single_session_422_100720_ch8\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch8\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch8\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [9]
# ✓ Resulting channel indices: [31]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [31]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [31]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 31 (1/1)
#   Channel 31 power range: 6.32e-09 - 1.21e+01
#   Channel 31 z-score range: -0.90 - 23.26
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.90 - 23.26
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch9
# Main results: results/single_session_422_100720_ch9\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch9\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch9\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [10]
# ✓ Resulting channel indices: [0]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [0]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [0]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 0 (1/1)
#   Channel 0 power range: 1.46e-09 - 6.44e-01
#   Channel 0 z-score range: -1.02 - 19.25
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.02 - 19.25
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch10
# Main results: results/single_session_422_100720_ch10\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch10\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch10\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [11]
# ✓ Resulting channel indices: [1]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [1]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [1]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 1 (1/1)
#   Channel 1 power range: 4.97e-09 - 6.93e-01
#   Channel 1 z-score range: -1.01 - 16.85
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.01 - 16.85
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch11
# Main results: results/single_session_422_100720_ch11\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch11\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch11\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [12]
# ✓ Resulting channel indices: [2]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [2]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [2]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 2 (1/1)
#   Channel 2 power range: 1.60e-09 - 7.15e-01
#   Channel 2 z-score range: -1.02 - 13.18
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.02 - 13.18
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch12
# Main results: results/single_session_422_100720_ch12\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch12\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch12\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [13]
# ✓ Resulting channel indices: [3]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [3]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [3]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 3 (1/1)
#   Channel 3 power range: 9.29e-09 - 1.71e+00
#   Channel 3 z-score range: -1.01 - 16.27
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.01 - 16.27
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch13
# Main results: results/single_session_422_100720_ch13\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch13\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch13\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [14]
# ✓ Resulting channel indices: [4]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [4]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [4]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 4 (1/1)
#   Channel 4 power range: 2.62e-09 - 9.52e-01
#   Channel 4 z-score range: -1.02 - 12.01
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.02 - 12.01
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch14
# Main results: results/single_session_422_100720_ch14\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch14\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch14\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [15]
# ✓ Resulting channel indices: [5]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [5]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [5]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 5 (1/1)
#   Channel 5 power range: 3.97e-10 - 8.48e-01
#   Channel 5 z-score range: -1.02 - 13.76
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.02 - 13.76
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch15
# Main results: results/single_session_422_100720_ch15\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch15\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch15\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [16]
# ✓ Resulting channel indices: [6]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [6]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [6]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 6 (1/1)
#   Channel 6 power range: 4.33e-10 - 1.39e+00
#   Channel 6 z-score range: -0.93 - 22.92
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.93 - 22.92
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch16
# Main results: results/single_session_422_100720_ch16\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch16\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch16\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [17]
# ✓ Resulting channel indices: [7]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [7]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [7]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 7 (1/1)
#   Channel 7 power range: 1.91e-09 - 3.18e-01
#   Channel 7 z-score range: -1.04 - 17.25
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.04 - 17.25
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch17
# Main results: results/single_session_422_100720_ch17\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch17\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch17\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [18]
# ✓ Resulting channel indices: [8]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [8]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [8]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 8 (1/1)
#   Channel 8 power range: 4.72e-10 - 6.29e-01
#   Channel 8 z-score range: -1.01 - 19.98
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.01 - 19.98
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch18
# Main results: results/single_session_422_100720_ch18\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch18\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch18\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [19]
# ✓ Resulting channel indices: [9]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [9]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [9]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 9 (1/1)
#   Channel 9 power range: 5.12e-10 - 6.69e-01
#   Channel 9 z-score range: -0.89 - 20.54
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.89 - 20.54
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch19
# Main results: results/single_session_422_100720_ch19\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch19\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch19\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [20]
# ✓ Resulting channel indices: [11]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [11]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [11]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 11 (1/1)
#   Channel 11 power range: 2.27e-10 - 1.24e+00
#   Channel 11 z-score range: -1.06 - 13.32
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.06 - 13.32
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch20
# Main results: results/single_session_422_100720_ch20\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch20\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch20\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [21]
# ✓ Resulting channel indices: [12]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [12]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [12]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 12 (1/1)
#   Channel 12 power range: 2.16e-10 - 7.50e+00
#   Channel 12 z-score range: -0.78 - 40.10
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.78 - 40.10
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# ...
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [26]
# ✓ Resulting channel indices: [17]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [17]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [17]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 17 (1/1)
#   Channel 17 power range: 2.27e-09 - 1.02e+00
#   Channel 17 z-score range: -1.05 - 12.50
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.05 - 12.50
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch26
# Main results: results/single_session_422_100720_ch26\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch26\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch26\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [27]
# ✓ Resulting channel indices: [18]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [18]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [18]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 18 (1/1)
#   Channel 18 power range: 6.42e-10 - 6.87e-01
#   Channel 18 z-score range: -0.95 - 26.05
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.95 - 26.05
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch27
# Main results: results/single_session_422_100720_ch27\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch27\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch27\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [28]
# ✓ Resulting channel indices: [19]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [19]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [19]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 19 (1/1)
#   Channel 19 power range: 1.37e-09 - 4.31e-01
#   Channel 19 z-score range: -0.95 - 16.59
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.95 - 16.59
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch28
# Main results: results/single_session_422_100720_ch28\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch28\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch28\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [29]
# ✓ Resulting channel indices: [20]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [20]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [20]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 20 (1/1)
#   Channel 20 power range: 1.57e-09 - 7.36e-01
#   Channel 20 z-score range: -1.06 - 11.96
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.06 - 11.96
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch29
# Main results: results/single_session_422_100720_ch29\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch29\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch29\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [30]
# ✓ Resulting channel indices: [22]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [22]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [22]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 22 (1/1)
#   Channel 22 power range: 1.73e-09 - 1.39e+00
#   Channel 22 z-score range: -0.84 - 22.70
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.84 - 22.70
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch30
# Main results: results/single_session_422_100720_ch30\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch30\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch30\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [31]
# ✓ Resulting channel indices: [23]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [23]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [23]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 23 (1/1)
#   Channel 23 power range: 2.21e-09 - 5.60e-01
#   Channel 23 z-score range: -0.91 - 17.32
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -0.91 - 17.32
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch31
# Main results: results/single_session_422_100720_ch31\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch31\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch31\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ Custom channel specification: [32]
# ✓ Resulting channel indices: [24]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-10 Hz)
# Computing ROI theta spectrogram for 1 channels...
# ROI channels: [24]
# 📊 PROCESSING VERIFICATION:
#    Using 1 channels: [24]
#    EEG data shape: (32, 407082)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 25 logarithmically spaced frequencies:
#    Range: 2.00 - 10.00 Hz
#    Frequencies: ['2.00', '2.14', '2.29', '2.45', '2.62', '2.80', '2.99', '3.20', '3.42', '3.66', '3.91', '4.18', '4.47', '4.78', '5.11', '5.47', '5.85', '6.25', '6.69', '7.15', '7.65', '8.18', '8.74', '9.35', '10.00']
#    N-cycles: ['6.0', '6.4', '6.9', '7.3', '7.8', '8.4', '9.0', '9.6', '10.3', '11.0', '11.7', '12.5', '13.4', '14.3', '15.3', '16.4', '17.5', '18.8', '20.1', '21.5', '22.9', '24.5', '26.2', '28.1', '30.0']
# Processing channel 24 (1/1)
#   Channel 24 power range: 5.83e-10 - 2.76e-01
#   Channel 24 z-score range: -1.03 - 13.38
# ROI spectrogram computed. Shape: (25, 407082)
# ROI z-score range: -1.03 - 13.38
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 55 valid events
# NM size 2.0: 57 valid events
# NM size 3.0: 51 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to results/single_session_422_100720_ch32
# Main results: results/single_session_422_100720_ch32\nm_roi_theta_analysis_results.pkl
# Summary: results/single_session_422_100720_ch32\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: results/single_session_422_100720_ch32\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================

# %% [markdown]
# ## 4. Multi-Session Analysis
#
# Analyze theta oscillations across all sessions for a specific rat.

# %%
# === MULTI-SESSION ANALYSIS PARAMETERS ===
rat_id = "531"                       # Which rat to analyze
roi_specification = 'frontal'        # ROI name or list of channels
freq_range = (2, 8)                  # Frequency range in Hz
n_freqs = 30                         # Number of log-spaced frequencies
window_duration = 1.0                # Event window duration
n_cycles_factor = 3.0                # Cycles per frequency factor
save_results = True                  # Whether to save results
show_plots = True                    # Whether to show plots

print(f"🔬 Running Multi-Session Analysis...")
print(f"   Rat ID: {rat_id}")
print(f"   ROI: {roi_specification}")
print(f"   Frequency range: {freq_range[0]}-{freq_range[1]} Hz ({n_freqs} frequencies)")
print(f"   Window: ±{window_duration/2:.1f}s around events")

# Find sessions for this rat
rat_sessions = []
for i, session in enumerate(all_eeg_data):
    if session.get('rat_id') == rat_id:
        rat_sessions.append((i, session))

print(f"   Found {len(rat_sessions)} sessions for rat {rat_id}")

if len(rat_sessions) == 0:
    print(f"❌ No sessions found for rat {rat_id}")
    print(f"Available rats: {sorted(rat_ids)}")
else:
    # Show session details
    total_events = 0
    for session_idx, session in rat_sessions:
        nm_events = len(session.get('nm_peak_times', []))
        total_events += nm_events
        print(f"     Session {session_idx}: {session.get('session_date', 'unknown')} - {nm_events} events")
    print(f"   Total NM events: {total_events}")
    
    # Run multi-session analysis using our pre-loaded data
    try:
        # We need to create a modified version that uses our pre-loaded data
        # Instead of loading from pickle file
        
        print(f"\n🚀 Starting multi-session analysis...")
        
        # Create a simple wrapper that uses our pre-loaded data
        def analyze_rat_multi_session_preloaded(rat_id, roi_or_channels, all_data, **kwargs):
            """Modified version that uses pre-loaded data."""
            # Filter sessions for this rat
            rat_sessions = []
            for i, session_data in enumerate(all_data):
                if session_data.get('rat_id') == rat_id:
                    rat_sessions.append((i, session_data))
            
            if not rat_sessions:
                raise ValueError(f"No sessions found for rat {rat_id}")
            
            # Analyze each session
            session_results = []
            for orig_session_idx, session_data in rat_sessions:
                print(f"Analyzing session {orig_session_idx}...")
                try:
                    result = analyze_session_nm_theta_roi(
                        session_data=session_data,
                        roi_or_channels=roi_or_channels,
                        mapping_df=electrode_mappings,
                        show_plots=True,  # Don't show individual session plots
                        **kwargs
                    )
                    session_results.append(result)
                except Exception as e:
                    print(f"⚠️  Session {orig_session_idx} failed: {e}")
                    continue
            
            if not session_results:
                raise ValueError("No sessions analyzed successfully")
            
            # Combine results (simplified version)
            combined_results = {
                'rat_id': rat_id,
                'roi_or_channels': roi_or_channels,
                'session_results': session_results,
                'n_sessions': len(session_results),
                'total_events': sum(len(r['normalized_windows']) for r in session_results)
            }
            
            return combined_results
        
        # Run the analysis
        multi_results = analyze_rat_multi_session_preloaded(
            rat_id=rat_id,
            roi_or_channels=roi_specification,
            all_data=all_eeg_data,
            freq_range=freq_range,
            n_freqs=n_freqs,
            window_duration=window_duration,
            n_cycles_factor=n_cycles_factor
        )
        
        print(f"\n✅ Multi-session analysis completed successfully!")
        print(f"   Rat: {multi_results['rat_id']}")
        print(f"   Sessions analyzed: {multi_results['n_sessions']}")
        print(f"   Total events: {multi_results['total_events']}")
        
        # Store results for later use
        last_multi_session_results = multi_results
        
        # Show summary statistics
        if multi_results['session_results']:
            roi_channels = multi_results['session_results'][0]['roi_channels']
            freqs = multi_results['session_results'][0]['freqs']
            print(f"   ROI channels: {roi_channels}")
            print(f"   Frequency range: {freqs[0]:.2f} - {freqs[-1]:.2f} Hz")
        
    except Exception as e:
        print(f"❌ Multi-session analysis failed: {e}")
        import traceback
        traceback.print_exc()
# Out:
# 🔬 Running Multi-Session Analysis...
#    Rat ID: 531
#    ROI: frontal
#    Frequency range: 2-8 Hz (30 frequencies)
#    Window: ±0.5s around events
#    Found 36 sessions for rat 531
#      Session 161: 010720 - 259 events
#      Session 162: 020720 - 251 events
#      Session 163: 030720 - 164 events
#      Session 164: 040720 - 74 events
#      Session 165: 050720 - 19 events
#      Session 166: 070720 - 76 events
#      Session 167: 080720 - 128 events
#      Session 168: 090720 - 160 events
#      Session 169: 090820 - 164 events
#      Session 170: 100720 - 175 events
#      Session 171: 110720 - 200 events
#      Session 172: 120720 - 248 events
#      Session 173: 120820 - 167 events
#      Session 174: 130820 - 209 events
#      Session 175: 140820 - 57 events
#      Session 176: 150820 - 170 events
#      Session 177: 160720 - 178 events
#      Session 178: 160820 - 15 events
#      Session 179: 170720 - 174 events
#      Session 180: 170820 - 31 events
#      Session 181: 180820 - 59 events
#      Session 182: 190820 - 117 events
#      Session 183: 200720 - 260 events
#      Session 184: 200820 - 125 events
#      Session 185: 210720 - 259 events
#      Session 186: 210820 - 31 events
#      Session 187: 220720 - 134 events
#      Session 188: 220820 - 29 events
#      Session 189: 230720 - 102 events
#      Session 190: 230820 - 76 events
#      Session 191: 240720 - 101 events
#      Session 192: 240820 - 134 events
#      Session 193: 260720 - 140 events
#      Session 194: 300620 - 243 events
#      Session 195: 300720 - 238 events
#      Session 196: 310720 - 274 events
#    Total NM events: 5241
#
# 🚀 Starting multi-session analysis...
# Analyzing session 161...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 386269)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 2.86e-09 - 9.44e-01
#   Channel 20 z-score range: -1.07 - 16.91
# Processing channel 21 (2/4)
#   Channel 21 power range: 1.33e-11 - 6.41e-01
#   Channel 21 z-score range: -0.82 - 41.06
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.63e-10 - 4.21e-01
#   Channel 23 z-score range: -0.83 - 21.89
# Processing channel 24 (4/4)
#   Channel 24 power range: 8.21e-10 - 6.64e+00
#   Channel 24 z-score range: -0.69 - 20.15
# ROI spectrogram computed. Shape: (30, 386269)
# ROI z-score range: -0.83 - 10.85
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 94 valid events
# NM size 2.0: 98 valid events
# NM size 3.0: 67 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 162...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 371165)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 7.75e-09 - 1.51e+00
#   Channel 20 z-score range: -0.90 - 30.18
# Processing channel 21 (2/4)
#   Channel 21 power range: 7.84e-11 - 1.22e+00
#   Channel 21 z-score range: -0.30 - 74.64
# Processing channel 23 (3/4)
#   Channel 23 power range: 1.10e-10 - 7.02e-01
#   Channel 23 z-score range: -0.61 - 43.17
# Processing channel 24 (4/4)
#   Channel 24 power range: 7.20e-11 - 2.20e+00
#   Channel 24 z-score range: -0.40 - 56.21
# ROI spectrogram computed. Shape: (30, 371165)
# ROI z-score range: -0.48 - 26.58
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 169 valid events
# NM size 2.0: 47 valid events
# NM size 3.0: 35 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 163...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 446400)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 2.47e-09 - 1.60e+00
#   Channel 20 z-score range: -1.06 - 21.00
# Processing channel 21 (2/4)
#   Channel 21 power range: 1.21e-09 - 1.50e+01
#   Channel 21 z-score range: -0.35 - 42.72
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.46e-10 - 4.88e-01
#   Channel 23 z-score range: -0.79 - 23.27
# Processing channel 24 (4/4)
#   Channel 24 power range: 3.19e-09 - 8.63e+00
#   Channel 24 z-score range: -0.78 - 38.07
# ROI spectrogram computed. Shape: (30, 446400)
# ROI z-score range: -0.72 - 12.78
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 71 valid events
# NM size 2.0: 58 valid events
# NM size 3.0: 35 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 164...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 531248)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.64e-09 - 1.56e+00
#   Channel 20 z-score range: -1.16 - 30.91
# Processing channel 21 (2/4)
#   Channel 21 power range: 2.44e-09 - 9.90e+00
#   Channel 21 z-score range: -0.50 - 39.57
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.90e-10 - 2.94e-01
#   Channel 23 z-score range: -0.81 - 45.86
# Processing channel 24 (4/4)
#   Channel 24 power range: 3.78e-09 - 7.81e+00
#   Channel 24 z-score range: -0.86 - 35.03
# ROI spectrogram computed. Shape: (30, 531248)
# ROI z-score range: -0.80 - 20.55
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 31 valid events
# NM size 2.0: 25 valid events
# NM size 3.0: 18 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 165...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 519584)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 1.73e-09 - 9.78e-01
#   Channel 20 z-score range: -1.19 - 16.08
# Processing channel 21 (2/4)
#   Channel 21 power range: 9.89e-11 - 2.26e+00
#   Channel 21 z-score range: -0.75 - 78.11
# Processing channel 23 (3/4)
#   Channel 23 power range: 8.16e-11 - 7.52e-01
#   Channel 23 z-score range: -0.88 - 29.27
# Processing channel 24 (4/4)
#   Channel 24 power range: 4.76e-09 - 3.89e+00
#   Channel 24 z-score range: -0.83 - 24.60
# ROI spectrogram computed. Shape: (30, 519584)
# ROI z-score range: -0.91 - 21.95
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 4 valid events
# NM size 2.0: 5 valid events
# NM size 3.0: 10 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 166...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 497639)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.46e-09 - 1.64e+00
#   Channel 20 z-score range: -1.14 - 24.10
# Processing channel 21 (2/4)
#   Channel 21 power range: 1.22e-07 - 6.82e+01
#   Channel 21 z-score range: -0.80 - 12.58
# Processing channel 23 (3/4)
#   Channel 23 power range: 4.32e-11 - 2.64e+00
#   Channel 23 z-score range: -0.82 - 65.06
# Processing channel 24 (4/4)
#   Channel 24 power range: 6.85e-10 - 7.50e+00
#   Channel 24 z-score range: -0.85 - 29.22
# ROI spectrogram computed. Shape: (30, 497639)
# ROI z-score range: -0.88 - 21.94
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 7 valid events
# NM size 2.0: 32 valid events
# NM size 3.0: 37 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 167...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 516701)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 7.75e-10 - 8.28e-01
#   Channel 20 z-score range: -1.18 - 15.32
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.87e-08 - 2.91e+01
#   Channel 21 z-score range: -0.60 - 23.38
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.55e-10 - 2.19e-01
#   Channel 23 z-score range: -0.89 - 19.86
# Processing channel 24 (4/4)
#   Channel 24 power range: 7.72e-10 - 8.85e+00
#   Channel 24 z-score range: -0.88 - 32.69
# ROI spectrogram computed. Shape: (30, 516701)
# ROI z-score range: -0.86 - 9.96
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 6 valid events
# NM size 2.0: 58 valid events
# NM size 3.0: 64 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 168...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 473428)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 5.38e-10 - 1.74e+00
#   Channel 20 z-score range: -1.15 - 25.09
# Processing channel 21 (2/4)
#   Channel 21 power range: 9.53e-09 - 1.75e+01
#   Channel 21 z-score range: -0.70 - 17.48
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.70e-10 - 1.72e+00
#   Channel 23 z-score range: -0.82 - 65.53
# Processing channel 24 (4/4)
#   Channel 24 power range: 1.66e-10 - 6.45e+00
#   Channel 24 z-score range: -0.90 - 24.43
# ROI spectrogram computed. Shape: (30, 473428)
# ROI z-score range: -0.85 - 23.57
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 28 valid events
# NM size 2.0: 84 valid events
# NM size 3.0: 48 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 169...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 406416)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 2.25e-10 - 6.22e-01
#   Channel 20 z-score range: -1.08 - 21.10
# Processing channel 21 (2/4)
#   Channel 21 power range: 2.29e-09 - 3.55e+01
#   Channel 21 z-score range: -0.58 - 23.43
# Processing channel 23 (3/4)
#   Channel 23 power range: 5.16e-10 - 3.26e-01
#   Channel 23 z-score range: -0.94 - 31.08
# Processing channel 24 (4/4)
#   Channel 24 power range: 1.28e-09 - 2.11e-01
#   Channel 24 z-score range: -1.05 - 15.24
# ROI spectrogram computed. Shape: (30, 406416)
# ROI z-score range: -0.88 - 10.36
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 62 valid events
# NM size 2.0: 67 valid events
# NM size 3.0: 35 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 170...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 492093)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 6.06e-11 - 1.14e+00
#   Channel 20 z-score range: -1.19 - 26.32
# Processing channel 21 (2/4)
#   Channel 21 power range: 8.36e-11 - 3.50e+00
#   Channel 21 z-score range: -0.59 - 31.13
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.42e-10 - 4.72e-01
#   Channel 23 z-score range: -0.93 - 28.45
# Processing channel 24 (4/4)
#   Channel 24 power range: 6.05e-10 - 4.41e+00
#   Channel 24 z-score range: -0.95 - 25.37
# ROI spectrogram computed. Shape: (30, 492093)
# ROI z-score range: -0.89 - 11.41
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 8 valid events
# NM size 2.0: 72 valid events
# NM size 3.0: 95 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 171...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 472410)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 1.69e-09 - 1.29e+00
#   Channel 20 z-score range: -1.14 - 22.96
# Processing channel 21 (2/4)
#   Channel 21 power range: 6.30e-08 - 4.70e+01
#   Channel 21 z-score range: -0.85 - 14.43
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.33e-10 - 4.20e-01
#   Channel 23 z-score range: -0.84 - 29.92
# Processing channel 24 (4/4)
#   Channel 24 power range: 3.75e-09 - 4.52e+00
#   Channel 24 z-score range: -0.92 - 42.80
# ROI spectrogram computed. Shape: (30, 472410)
# ROI z-score range: -0.90 - 17.56
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 27 valid events
# NM size 2.0: 109 valid events
# NM size 3.0: 64 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 172...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 483988)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 8.26e-10 - 9.92e-01
#   Channel 20 z-score range: -1.16 - 12.74
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.12e-07 - 6.95e+01
#   Channel 21 z-score range: -0.90 - 18.41
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.36e-11 - 5.27e-01
#   Channel 23 z-score range: -0.84 - 47.80
# Processing channel 24 (4/4)
#   Channel 24 power range: 3.66e-10 - 2.84e+00
#   Channel 24 z-score range: -0.95 - 26.12
# ROI spectrogram computed. Shape: (30, 483988)
# ROI z-score range: -0.90 - 20.72
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 10 valid events
# NM size 2.0: 86 valid events
# NM size 3.0: 152 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 173...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 428285)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.01e-12 - 2.45e+00
#   Channel 20 z-score range: -1.06 - 34.10
# Processing channel 21 (2/4)
#   Channel 21 power range: 2.87e-10 - 2.34e+00
#   Channel 21 z-score range: -0.89 - 51.40
# Processing channel 23 (3/4)
#   Channel 23 power range: 1.59e-10 - 2.38e+00
#   Channel 23 z-score range: -0.79 - 53.01
# Processing channel 24 (4/4)
#   Channel 24 power range: 6.12e-11 - 1.39e+00
#   Channel 24 z-score range: -0.50 - 62.48
# ROI spectrogram computed. Shape: (30, 428285)
# ROI z-score range: -0.80 - 37.32
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 65 valid events
# NM size 2.0: 25 valid events
# NM size 3.0: 77 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 174...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 390708)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 7.95e-09 - 8.42e-01
#   Channel 20 z-score range: -1.04 - 24.79
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.85e-10 - 3.44e-01
#   Channel 21 z-score range: -0.94 - 36.29
# Processing channel 23 (3/4)
#   Channel 23 power range: 4.43e-11 - 1.07e-01
#   Channel 23 z-score range: -0.90 - 16.69
# Processing channel 24 (4/4)
#   Channel 24 power range: 1.26e-10 - 6.10e-02
#   Channel 24 z-score range: -1.00 - 30.42
# ROI spectrogram computed. Shape: (30, 390708)
# ROI z-score range: -0.93 - 20.43
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 114 valid events
# NM size 2.0: 45 valid events
# NM size 3.0: 50 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 175...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 532244)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.38e-10 - 7.82e-01
#   Channel 20 z-score range: -1.14 - 16.50
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.37e-10 - 1.54e+00
#   Channel 21 z-score range: -0.74 - 29.20
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.13e-10 - 1.15e-01
#   Channel 23 z-score range: -1.07 - 20.21
# Processing channel 24 (4/4)
#   Channel 24 power range: 5.48e-11 - 1.01e-01
#   Channel 24 z-score range: -1.05 - 26.90
# ROI spectrogram computed. Shape: (30, 532244)
# ROI z-score range: -0.98 - 9.15
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 3 valid events
# NM size 2.0: 12 valid events
# NM size 3.0: 42 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 176...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 391588)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 4.10e-09 - 5.50e-01
#   Channel 20 z-score range: -0.98 - 11.06
# Processing channel 21 (2/4)
#   Channel 21 power range: 2.09e-10 - 1.82e+00
#   Channel 21 z-score range: -0.70 - 31.13
# Processing channel 23 (3/4)
#   Channel 23 power range: 1.81e-10 - 1.89e-01
# ...
# Processing channel 24 (4/4)
#   Channel 24 power range: 8.83e-12 - 1.45e+00
#   Channel 24 z-score range: -0.97 - 24.06
# ROI spectrogram computed. Shape: (30, 493805)
# ROI z-score range: -0.82 - 28.15
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 31 valid events
# NM size 2.0: 32 valid events
# NM size 3.0: 38 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 192...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (31, 413661)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.87e-09 - 1.65e+01
#   Channel 20 z-score range: -0.45 - 31.31
# Processing channel 21 (2/4)
#   Channel 21 power range: 4.17e-11 - 3.72e-01
#   Channel 21 z-score range: -0.77 - 40.36
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.77e-10 - 6.31e-01
#   Channel 23 z-score range: -1.04 - 22.04
# Processing channel 24 (4/4)
#   Channel 24 power range: 2.86e-09 - 2.13e+01
#   Channel 24 z-score range: -0.37 - 30.98
# ROI spectrogram computed. Shape: (30, 413661)
# ROI z-score range: -0.61 - 14.97
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 65 valid events
# NM size 2.0: 36 valid events
# NM size 3.0: 33 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 193...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 481562)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 3.12e-09 - 6.38e-01
#   Channel 20 z-score range: -1.11 - 14.41
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.10e-09 - 4.20e+01
#   Channel 21 z-score range: -0.67 - 16.73
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.60e-10 - 3.31e-01
#   Channel 23 z-score range: -0.96 - 28.24
# Processing channel 24 (4/4)
#   Channel 24 power range: 8.32e-10 - 1.33e+00
#   Channel 24 z-score range: -1.07 - 23.48
# ROI spectrogram computed. Shape: (30, 481562)
# ROI z-score range: -0.91 - 10.06
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 35 valid events
# NM size 2.0: 38 valid events
# NM size 3.0: 67 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 194...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 416103)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 8.47e-09 - 7.50e+00
#   Channel 20 z-score range: -0.94 - 12.66
# Processing channel 21 (2/4)
#   Channel 21 power range: 4.12e-09 - 8.68e+00
#   Channel 21 z-score range: -0.74 - 30.08
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.35e-10 - 6.25e+00
#   Channel 23 z-score range: -0.54 - 12.53
# Processing channel 24 (4/4)
#   Channel 24 power range: 6.05e-10 - 1.15e+01
#   Channel 24 z-score range: -0.66 - 21.75
# ROI spectrogram computed. Shape: (30, 416103)
# ROI z-score range: -0.65 - 8.46
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 83 valid events
# NM size 2.0: 100 valid events
# NM size 3.0: 60 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 195...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 438429)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 5.33e-11 - 9.85e-01
#   Channel 20 z-score range: -1.07 - 11.92
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.54e-08 - 5.73e+01
#   Channel 21 z-score range: -0.69 - 20.61
# Processing channel 23 (3/4)
#   Channel 23 power range: 2.81e-10 - 8.19e-01
#   Channel 23 z-score range: -0.67 - 20.34
# Processing channel 24 (4/4)
#   Channel 24 power range: 1.04e-10 - 1.29e+00
#   Channel 24 z-score range: -0.97 - 22.18
# ROI spectrogram computed. Shape: (30, 438429)
# ROI z-score range: -0.80 - 9.25
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 64 valid events
# NM size 2.0: 47 valid events
# NM size 3.0: 127 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
# Analyzing session 196...
# ============================================================
# NM THETA ROI ANALYSIS
# ============================================================
# Step 1: Determining ROI channels
# ============================================================
# 🔍 ELECTRODE MAPPING VERIFICATION
# ============================================================
# ✓ ROI specification: 'frontal'
# ✓ ROI_MAP['frontal'] = [2, 29, 31, 32]
# ✓ Rat 531 electrode mapping:
#    Electrode  2 -> Channel index 21
#    Electrode 29 -> Channel index 20
#    Electrode 31 -> Channel index 23
#    Electrode 32 -> Channel index 24
# ✓ Final channel indices: [20, 21, 23, 24]
# ✓ EEG data access: eeg_data[[20, 21, 23, 24], :]
# ============================================================
# Step 2: Computing ROI theta spectrogram (2-8 Hz)
# Computing ROI theta spectrogram for 4 channels...
# ROI channels: [20, 21, 23, 24]
# 📊 PROCESSING VERIFICATION:
#    Using 4 channels: [20, 21, 23, 24]
#    EEG data shape: (32, 404567)
#    Each channel will be z-score normalized individually, then averaged
# 📊 Using 30 logarithmically spaced frequencies:
#    Range: 2.00 - 8.00 Hz
#    Frequencies: ['2.00', '2.10', '2.20', '2.31', '2.42', '2.54', '2.66', '2.79', '2.93', '3.08', '3.23', '3.38', '3.55', '3.72', '3.91', '4.10', '4.30', '4.51', '4.73', '4.96', '5.20', '5.46', '5.72', '6.01', '6.30', '6.61', '6.93', '7.27', '7.63', '8.00']
#    N-cycles: ['6.0', '6.3', '6.6', '6.9', '7.3', '7.6', '8.0', '8.4', '8.8', '9.2', '9.7', '10.2', '10.6', '11.2', '11.7', '12.3', '12.9', '13.5', '14.2', '14.9', '15.6', '16.4', '17.2', '18.0', '18.9', '19.8', '20.8', '21.8', '22.9', '24.0']
# Processing channel 20 (1/4)
#   Channel 20 power range: 1.67e-09 - 1.15e+00
#   Channel 20 z-score range: -1.05 - 21.15
# Processing channel 21 (2/4)
#   Channel 21 power range: 3.85e-08 - 2.28e+01
#   Channel 21 z-score range: -0.69 - 26.73
# Processing channel 23 (3/4)
#   Channel 23 power range: 3.85e-10 - 1.75e+00
#   Channel 23 z-score range: -0.96 - 51.50
# Processing channel 24 (4/4)
#   Channel 24 power range: 7.47e-10 - 2.51e+00
#   Channel 24 z-score range: -1.02 - 33.86
# ROI spectrogram computed. Shape: (30, 404567)
# ROI z-score range: -0.89 - 23.39
# Step 3: Using per-channel normalized ROI power
# Step 4: Extracting NM event windows
# Extracting NM event windows (±0.5s around events)...
# Found NM sizes: [1. 2. 3.]
# NM size 1.0: 104 valid events
# NM size 2.0: 62 valid events
# NM size 3.0: 108 valid events
# Step 5: ROI windows already normalized per channel
# Step 6: Saving results
# ROI results saved to nm_theta_results
# Main results: nm_theta_results\nm_roi_theta_analysis_results.pkl
# Summary: nm_theta_results\roi_analysis_summary.txt
# Step 7: Generating plots
# Generating ROI plots...
# ROI plot saved: nm_theta_results\nm_roi_theta_spectrograms.png
# Skipping frequency profiles plot (show_frequency_profiles=False)
# ============================================================
# ROI ANALYSIS COMPLETE!
# ============================================================
#
# ✅ Multi-session analysis completed successfully!
#    Rat: 531
#    Sessions analyzed: 36
#    Total events: 108
#    ROI channels: [20, 21, 23, 24]
#    Frequency range: 2.00 - 8.00 Hz

# %% [markdown]
# ## 5. Parameter Testing
#
# Different ROI or frequencies for one session

# %%
# === PARAMETER TESTING ===
test_session = 0
test_roi = 'hippocampus'  # Change this to test different ROIs

# Test different frequency ranges
freq_ranges_to_test = [
    (3, 8),    # Classic theta
    (2, 10),   # Extended theta
    (4, 12),   # Theta + low alpha
]

print(f"🧪 Testing different frequency ranges on session {test_session} with ROI '{test_roi}'")

session_data = all_eeg_data[test_session]
print(f"Session: Rat {session_data.get('rat_id')}, {len(session_data['nm_peak_times'])} NM events\n")

for i, freq_range in enumerate(freq_ranges_to_test):
    print(f"📊 Test {i+1}: {freq_range[0]}-{freq_range[1]} Hz")
    
    try:
        # Quick analysis without saving or plotting
        results = analyze_session_nm_theta_roi(
            session_data=session_data,
            roi_or_channels=test_roi,
            freq_range=freq_range,
            n_freqs=20,
            window_duration=1.0,
            mapping_df=electrode_mappings,
            show_plots=False,
            save_path=None
        )
        
        # Print summary
        roi_channels = results['roi_channels']
        freqs = results['freqs']
        windows = results['normalized_windows']
        
        print(f"   ✅ Success: {len(roi_channels)} channels, {len(freqs)} frequencies")
        print(f"      ROI channels: {roi_channels}")
        print(f"      Windows: {list(windows.keys())}")
        
        # Show some power statistics
        all_power = np.concatenate([w.flatten() for w in windows.values()])
        print(f"      Z-score range: {all_power.min():.2f} to {all_power.max():.2f}")
        print(f"      Z-score mean±std: {all_power.mean():.2f} ± {all_power.std():.2f}")
        
    except Exception as e:
        print(f"   ❌ Failed: {e}")
    
    print()

# %% [markdown]
# ## 7. Utility Functions
#
# Helper functions for common tasks.

# %%
def quick_session_info(session_idx):
    """Get quick info about a session."""
    if session_idx >= len(all_eeg_data):
        print(f"❌ Session {session_idx} out of range (0-{len(all_eeg_data)-1})")
        return
    
    session = all_eeg_data[session_idx]
    print(f"Session {session_idx}:")
    print(f"  Rat: {session.get('rat_id', 'unknown')}")
    print(f"  Date: {session.get('session_date', 'unknown')}")
    print(f"  Duration: {session['eeg_time'].flatten()[-1]:.1f}s")
    print(f"  NM events: {len(session['nm_peak_times'])}")
    print(f"  NM sizes: {np.unique(session['nm_sizes'])}")

def list_sessions_for_rat(rat_id):
    """List all sessions for a specific rat."""
    sessions = []
    for i, session in enumerate(all_eeg_data):
        if session.get('rat_id') == rat_id:
            sessions.append({
                'index': i,
                'date': session.get('session_date', 'unknown'),
                'nm_events': len(session.get('nm_peak_times', []))
            })
    
    if sessions:
        print(f"Sessions for rat {rat_id}:")
        for s in sessions:
            print(f"  [{s['index']}] {s['date']} - {s['nm_events']} events")
    else:
        print(f"No sessions found for rat {rat_id}")
    
    return sessions

def test_roi_channels(rat_id, roi_name):
    """Test which channels are available for a ROI."""
    try:
        channels = get_channels(rat_id, roi_name, electrode_mappings)
        print(f"ROI '{roi_name}' for rat {rat_id}: {channels}")
        return channels
    except Exception as e:
        print(f"ROI '{roi_name}' for rat {rat_id}: Not available ({e})")
        return None

# Example usage:
print("🛠️  Utility functions loaded. Examples:")
print("   quick_session_info(0)")
print("   list_sessions_for_rat(10501)")
print("   test_roi_channels(10501, 'frontal')")

# Quick demo:
if len(all_eeg_data) > 0:
    quick_session_info(0)

# %% [markdown]
# # RAT ID

# %%
from src.core.nm_theta_multi_session import (
    analyze_rat_multi_session,
    plot_multi_session_results,
    save_multi_session_results
)

# %%
# Process multiple rats
rat_ids = ["531"]  # Add all your rat IDs here
roi_specification = 'frontal'

for rat_id in rat_ids:
    print(f"\n=== Processing Rat {rat_id} ===")
    
    # Run multi-session analysis using pre-loaded data
    multi_results = analyze_rat_multi_session_preloaded(
        rat_id=rat_id,
        roi_or_channels=roi_specification,
        all_data=all_eeg_data,
        freq_range=freq_range,
        n_freqs=n_freqs,
        window_duration=window_duration,
        n_cycles_factor=n_cycles_factor
    )
    
    # Save results using organized structure
    save_path = f'results/multi_session/rat_{rat_id}'
    save_multi_session_results(multi_results, save_path)
    
    # Plot averaged results (but not individual sessions)
    plot_multi_session_results(multi_results, save_path)
    
    print(f"✅ Completed analysis for rat {rat_id}")

# %%
# Process multiple rats with better memory management
rat_ids = ["531"]  # Add other rat IDs as needed
roi_specification = 'frontal'
save_base_path = 'results/multi_session'

for rat_id in rat_ids:
    print(f"\n=== Processing Rat {rat_id} ===")
    save_path = f'{save_base_path}/rat_{rat_id}'
    
    # Find sessions for this rat
    rat_sessions = []
    for i, session in enumerate(all_eeg_data):
        if session.get('rat_id') == rat_id:
            rat_sessions.append((i, session))
    
    # Process each session individually but don't keep all results in memory
    print(f"Found {len(rat_sessions)} sessions for rat {rat_id}")
    session_results = []
    session_metadata = []
    
    for session_idx, (orig_idx, session_data) in enumerate(rat_sessions):
        print(f"Analyzing session {orig_idx}...")
        try:
            # Create a session-specific save path
            session_save_path = f'{save_path}/session_{orig_idx}'
            
            # Analyze this session
            result = analyze_session_nm_theta_roi(
                session_data=session_data,
                roi_or_channels=roi_specification,
                freq_range=freq_range,
                n_freqs=n_freqs,
                window_duration=window_duration,
                n_cycles_factor=n_cycles_factor,
                save_path=session_save_path,
                show_plots=False  # Don't plot individual sessions
            )
            
            # Save individual session results immediately
            with open(f'{session_save_path}/session_result.pkl', 'wb') as f:
                pickle.dump(result, f)
                
            # Store only metadata and minimal results for averaging
            light_result = {
                'roi_channels': result['roi_channels'],
                'freqs': result['freqs'],
                'roi_specification': result['roi_specification'],
                'normalized_windows': result['normalized_windows']
            }
            session_results.append(light_result)
            
            # Store metadata
            metadata = {
                'original_session_index': orig_idx,
                'session_date': session_data.get('session_date', 'unknown'),
                'rat_id': session_data.get('rat_id'),
                'roi_channels': result['roi_channels'],
                'total_nm_events': sum(data['n_events'] for data in result['normalized_windows'].values()),
                'nm_sizes': list(result['normalized_windows'].keys())
            }
            session_metadata.append(metadata)
            
            # Explicitly free memory after each session
            del result
            import gc
            gc.collect()
            
            print(f"✓ Session {session_idx + 1} completed successfully")
        
        except Exception as e:
            print(f"⚠️ Error processing session {orig_idx}: {e}")
            continue
    
    # Now average results across sessions
    if session_results:
        # Import the necessary functions
        from src.core.nm_theta_multi_session import average_session_results, save_multi_session_results, plot_multi_session_results
        
        # Average the results
        print("\nAveraging results across sessions...")
        averaged_results = average_session_results(session_results, session_metadata, rat_id)
        
        # Save multi-session results
        print("Saving multi-session results...")
        save_multi_session_results(averaged_results, save_path)
        
        # Plot multi-session results
        print("Plotting multi-session results...")
        plot_multi_session_results(averaged_results, save_path)
        
        print(f"✅ Completed multi-session analysis for rat {rat_id}")
    else:
        print(f"❌ No successful sessions to average for rat {rat_id}")
